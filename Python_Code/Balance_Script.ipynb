# %%
# Selecciona Balance y Período para descargar: 
BalanceFile = "Balance2024.csv"
Periodo = 'Anual' # 'Anual' si es Balance del Año. 'Q1'..'Q4' si es Trimestral.

# %% [markdown]
# ### Tranformación Automatizada Datos Holded:

# %%
import pandas as pd 
import numpy as np

# %%
# Importamos data:
    # BalanceFile = "Balance2022.csv"
    # Periodo = 'Anual'

Balance = pd.read_csv(f"/home/claude/holded/HoldedFiles/{BalanceFile}", header = None, sep = '\t')

# %%
# Renombramos nombres de columnas:
Balance = Balance.rename(columns={0 : 'Subcuenta', 1 : 'Valor'})

# %% [markdown]
# * 1. Partida:

# %%
# Creamos columna con el nombre de la partida:
Balance['Partida'] = Balance['Subcuenta'].where(Balance['Valor'].isna()).ffill()
# Borrar fila original donde Valor es NaN:
Balance = Balance[~Balance['Valor'].isna()]

# %%
Balance
# Out:
#                                     Subcuenta        Valor  \
# 1                         Activo No Corriente  158121,9386
# 2                  I. Inmovilizado intangible  71311,58042
# 3                5. Aplicaciones informáticas  71311,58042
# 4               206 Aplicaciones informáticas     923003,2
# 5    20600001 - CASH LESS DESARROLLO SOFTWARE     923003,2
# ..                                        ...          ...
# 121                     4709 Hacienda Pública      8171,91
# 141                                572 Bancos    680354,50
# 214                     4750 Hacienda Pública     33167,95
# 216                     4751 Hacienda Pública     34462,54
# 219     476 Organismos de la Seguridad Social     12845,25
#
#                                                Partida
# 1                                               ACTIVO
# 2                                               ACTIVO
# 3                                               ACTIVO
# 4                                               ACTIVO
# 5                                               ACTIVO
# ..                                                 ...
# 121                  5. Activos por impuesto corriente
# 141                                       1. Tesorería
# 214  6. Otras deudas con las Administraciones Públicas
# 216           47500000 - HACIENDA PÚBLICA ACREEDORA PO
# 219              47510001 - HP ACREED RETEN TRABAJADOR
#
# [107 rows x 3 columns]

# %% [markdown]
# * 2. Subpartida:

# %%
Subpartidas = pd.Series(['Activo No Corriente', 'Activo Corriente', 'Patrimonio Neto',
                       'Pasivo Corriente', 'Pasivo No Corriente'])
print(Subpartidas)
# Out:
# 0    Activo No Corriente
# 1       Activo Corriente
# 2        Patrimonio Neto
# 3       Pasivo Corriente
# 4    Pasivo No Corriente
# dtype: str

# %%
# 1. Creamos columna para filas con Subpartidas:
Balance['Subpartida'] = Balance['Subcuenta'].where(Balance['Subcuenta'].isin(Subpartidas)).ffill()
# 2. Eliminamos la columna con Subpartida Original:
Balance = Balance[~Balance['Subcuenta'].isin(Subpartidas)]

# %%
Balance
# Out:
#                                              Subcuenta         Valor  \
# 2                           I. Inmovilizado intangible   71311,58042
# 3                         5. Aplicaciones informáticas   71311,58042
# 4                        206 Aplicaciones informáticas      923003,2
# 5             20600001 - CASH LESS DESARROLLO SOFTWARE      923003,2
# 6    2806 Amortización acumulada de aplicaciones in...  -851691,6196
# ..                                                 ...           ...
# 121                              4709 Hacienda Pública       8171,91
# 141                                         572 Bancos     680354,50
# 214                              4750 Hacienda Pública      33167,95
# 216                              4751 Hacienda Pública      34462,54
# 219              476 Organismos de la Seguridad Social      12845,25
#
#                                                Partida           Subpartida
# 2                                               ACTIVO  Activo No Corriente
# 3                                               ACTIVO  Activo No Corriente
# 4                                               ACTIVO  Activo No Corriente
# 5                                               ACTIVO  Activo No Corriente
# 6                                               ACTIVO  Activo No Corriente
# ..                                                 ...                  ...
# 121                  5. Activos por impuesto corriente  Activo No Corriente
# 141                                       1. Tesorería  Activo No Corriente
# 214  6. Otras deudas con las Administraciones Públicas  Activo No Corriente
# 216           47500000 - HACIENDA PÚBLICA ACREEDORA PO  Activo No Corriente
# 219              47510001 - HP ACREED RETEN TRABAJADOR  Activo No Corriente
#
# [106 rows x 4 columns]

# %% [markdown]
# * 3. Grupo:

# %%
Grupo_id = pd.Series(['I', 'II', 'III', 'IV', 'V', 'VI', 'VII', 'VIII', 'IX', 'X'])

# %%
Grupo_id = Grupo_id.tolist()

# %%
# Para crear columna Grupo:
Balance['Grupo'] = Balance['Subcuenta'].where(Balance['Subcuenta'].str.startswith(tuple(Grupo_id))).ffill()
# Para Borrar Filas Grupo Original:
Balance = Balance[~Balance['Subcuenta'].str.startswith(tuple(Grupo_id))]

# %%
Balance
# Out:
#                                              Subcuenta         Valor  \
# 3                         5. Aplicaciones informáticas   71311,58042
# 4                        206 Aplicaciones informáticas      923003,2
# 5             20600001 - CASH LESS DESARROLLO SOFTWARE      923003,2
# 6    2806 Amortización acumulada de aplicaciones in...  -851691,6196
# 7                        28060001 - AMORTACUMCASH LESS  -851691,6196
# ..                                                 ...           ...
# 121                              4709 Hacienda Pública       8171,91
# 141                                         572 Bancos     680354,50
# 214                              4750 Hacienda Pública      33167,95
# 216                              4751 Hacienda Pública      34462,54
# 219              476 Organismos de la Seguridad Social      12845,25
#
#                                                Partida           Subpartida  \
# 3                                               ACTIVO  Activo No Corriente
# 4                                               ACTIVO  Activo No Corriente
# 5                                               ACTIVO  Activo No Corriente
# 6                                               ACTIVO  Activo No Corriente
# 7                                               ACTIVO  Activo No Corriente
# ..                                                 ...                  ...
# 121                  5. Activos por impuesto corriente  Activo No Corriente
# 141                                       1. Tesorería  Activo No Corriente
# 214  6. Otras deudas con las Administraciones Públicas  Activo No Corriente
# 216           47500000 - HACIENDA PÚBLICA ACREEDORA PO  Activo No Corriente
# 219              47510001 - HP ACREED RETEN TRABAJADOR  Activo No Corriente
#
#                                  Grupo
# 3           I. Inmovilizado intangible
# 4           I. Inmovilizado intangible
# 5           I. Inmovilizado intangible
# 6           I. Inmovilizado intangible
# 7           I. Inmovilizado intangible
# ..                                 ...
# 121  VI. Activos por impuesto diferido
# 141  VI. Activos por impuesto diferido
# 214  VI. Activos por impuesto diferido
# 216  VI. Activos por impuesto diferido
# 219  VI. Activos por impuesto diferido
#
# [101 rows x 5 columns]

# %% [markdown]
# * Subgrupo:

# %%
Subgrupo_id = pd.Series(['1.', '2.', '3.', '4.', '5.', '6.', '7.',
                         '8.', '9.']).tolist()

# %%
# Creamos columna Subgrupo:
Balance['SubGrupo'] = Balance['Subcuenta'].where(Balance['Subcuenta'].str.startswith(tuple(Subgrupo_id))).ffill()
# Eliminamos columna original con Subgrupo:
Balance = Balance[~Balance['Subcuenta'].str.startswith(tuple(Subgrupo_id))]

# %%
Balance
# Out:
#                                              Subcuenta         Valor  \
# 4                        206 Aplicaciones informáticas      923003,2
# 5             20600001 - CASH LESS DESARROLLO SOFTWARE      923003,2
# 6    2806 Amortización acumulada de aplicaciones in...  -851691,6196
# 7                        28060001 - AMORTACUMCASH LESS  -851691,6196
# 10                                      216 Mobiliario   27302,08147
# ..                                                 ...           ...
# 121                              4709 Hacienda Pública       8171,91
# 141                                         572 Bancos     680354,50
# 214                              4750 Hacienda Pública      33167,95
# 216                              4751 Hacienda Pública      34462,54
# 219              476 Organismos de la Seguridad Social      12845,25
#
#                                                Partida           Subpartida  \
# 4                                               ACTIVO  Activo No Corriente
# 5                                               ACTIVO  Activo No Corriente
# 6                                               ACTIVO  Activo No Corriente
# 7                                               ACTIVO  Activo No Corriente
# 10                                              ACTIVO  Activo No Corriente
# ..                                                 ...                  ...
# 121                  5. Activos por impuesto corriente  Activo No Corriente
# 141                                       1. Tesorería  Activo No Corriente
# 214  6. Otras deudas con las Administraciones Públicas  Activo No Corriente
# 216           47500000 - HACIENDA PÚBLICA ACREEDORA PO  Activo No Corriente
# 219              47510001 - HP ACREED RETEN TRABAJADOR  Activo No Corriente
#
#                                  Grupo  \
# 4           I. Inmovilizado intangible
# 5           I. Inmovilizado intangible
# 6           I. Inmovilizado intangible
# 7           I. Inmovilizado intangible
# 10           II. Inmovilizado material
# ..                                 ...
# 121  VI. Activos por impuesto diferido
# 141  VI. Activos por impuesto diferido
# 214  VI. Activos por impuesto diferido
# 216  VI. Activos por impuesto diferido
# 219  VI. Activos por impuesto diferido
#
#                                               SubGrupo
# 4                         5. Aplicaciones informáticas
# 5                         5. Aplicaciones informáticas
# 6                         5. Aplicaciones informáticas
# 7                         5. Aplicaciones informáticas
# 10   2. Instalaciones técnicas y otro inmovilizado ...
# ..                                                 ...
# 121                       5. Otros activos financieros
# 141                       5. Otros activos financieros
# 214                       5. Otros activos financieros
# 216                       5. Otros activos financieros
# 219                       5. Otros activos financieros
#
# [97 rows x 6 columns]

# %% [markdown]
# * Cuenta:

# %%
print(Balance)
# Out:
#                                              Subcuenta         Valor  \
# 4                        206 Aplicaciones informáticas      923003,2
# 5             20600001 - CASH LESS DESARROLLO SOFTWARE      923003,2
# 6    2806 Amortización acumulada de aplicaciones in...  -851691,6196
# 7                        28060001 - AMORTACUMCASH LESS  -851691,6196
# 10                                      216 Mobiliario   27302,08147
# ..                                                 ...           ...
# 121                              4709 Hacienda Pública       8171,91
# 141                                         572 Bancos     680354,50
# 214                              4750 Hacienda Pública      33167,95
# 216                              4751 Hacienda Pública      34462,54
# 219              476 Organismos de la Seguridad Social      12845,25
#
#                                                Partida           Subpartida  \
# 4                                               ACTIVO  Activo No Corriente
# 5                                               ACTIVO  Activo No Corriente
# 6                                               ACTIVO  Activo No Corriente
# 7                                               ACTIVO  Activo No Corriente
# 10                                              ACTIVO  Activo No Corriente
# ..                                                 ...                  ...
# 121                  5. Activos por impuesto corriente  Activo No Corriente
# 141                                       1. Tesorería  Activo No Corriente
# 214  6. Otras deudas con las Administraciones Públicas  Activo No Corriente
# 216           47500000 - HACIENDA PÚBLICA ACREEDORA PO  Activo No Corriente
# 219              47510001 - HP ACREED RETEN TRABAJADOR  Activo No Corriente
#
#                                  Grupo  \
# 4           I. Inmovilizado intangible
# 5           I. Inmovilizado intangible
# 6           I. Inmovilizado intangible
# 7           I. Inmovilizado intangible
# 10           II. Inmovilizado material
# ..                                 ...
# 121  VI. Activos por impuesto diferido
# 141  VI. Activos por impuesto diferido
# 214  VI. Activos por impuesto diferido
# 216  VI. Activos por impuesto diferido
# 219  VI. Activos por impuesto diferido
#
#                                               SubGrupo
# 4                         5. Aplicaciones informáticas
# 5                         5. Aplicaciones informáticas
# 6                         5. Aplicaciones informáticas
# 7                         5. Aplicaciones informáticas
# 10   2. Instalaciones técnicas y otro inmovilizado ...
# ..                                                 ...
# 121                       5. Otros activos financieros
# 141                       5. Otros activos financieros
# 214                       5. Otros activos financieros
# 216                       5. Otros activos financieros
# 219                       5. Otros activos financieros
#
# [97 rows x 6 columns]

# %%
Balance['Subcuenta'].where(pd.to_numeric(Balance['Subcuenta'].str.extract(r'^(\d+)')[0]) < 1000).ffill()
# Out:
# 4              206 Aplicaciones informáticas
# 5              206 Aplicaciones informáticas
# 6              206 Aplicaciones informáticas
# 7              206 Aplicaciones informáticas
# 10                            216 Mobiliario
#                        ...
# 121        474 Activos por impuesto diferido
# 141                               572 Bancos
# 214                               572 Bancos
# 216                               572 Bancos
# 219    476 Organismos de la Seguridad Social
# Name: Subcuenta, Length: 97, dtype: str

# %%
Balance['Cuenta'] = Balance['Subcuenta'].where(pd.to_numeric(Balance['Subcuenta'].str.extract(r'^(\d+)')[0]) < 10000).ffill()

# %%
Balance
# Out:
#                                              Subcuenta         Valor  \
# 4                        206 Aplicaciones informáticas      923003,2
# 5             20600001 - CASH LESS DESARROLLO SOFTWARE      923003,2
# 6    2806 Amortización acumulada de aplicaciones in...  -851691,6196
# 7                        28060001 - AMORTACUMCASH LESS  -851691,6196
# 10                                      216 Mobiliario   27302,08147
# ..                                                 ...           ...
# 121                              4709 Hacienda Pública       8171,91
# 141                                         572 Bancos     680354,50
# 214                              4750 Hacienda Pública      33167,95
# 216                              4751 Hacienda Pública      34462,54
# 219              476 Organismos de la Seguridad Social      12845,25
#
#                                                Partida           Subpartida  \
# 4                                               ACTIVO  Activo No Corriente
# 5                                               ACTIVO  Activo No Corriente
# 6                                               ACTIVO  Activo No Corriente
# 7                                               ACTIVO  Activo No Corriente
# 10                                              ACTIVO  Activo No Corriente
# ..                                                 ...                  ...
# 121                  5. Activos por impuesto corriente  Activo No Corriente
# 141                                       1. Tesorería  Activo No Corriente
# 214  6. Otras deudas con las Administraciones Públicas  Activo No Corriente
# 216           47500000 - HACIENDA PÚBLICA ACREEDORA PO  Activo No Corriente
# 219              47510001 - HP ACREED RETEN TRABAJADOR  Activo No Corriente
#
#                                  Grupo  \
# 4           I. Inmovilizado intangible
# 5           I. Inmovilizado intangible
# 6           I. Inmovilizado intangible
# 7           I. Inmovilizado intangible
# 10           II. Inmovilizado material
# ..                                 ...
# 121  VI. Activos por impuesto diferido
# 141  VI. Activos por impuesto diferido
# 214  VI. Activos por impuesto diferido
# 216  VI. Activos por impuesto diferido
# 219  VI. Activos por impuesto diferido
#
#                                               SubGrupo  \
# 4                         5. Aplicaciones informáticas
# 5                         5. Aplicaciones informáticas
# 6                         5. Aplicaciones informáticas
# 7                         5. Aplicaciones informáticas
# 10   2. Instalaciones técnicas y otro inmovilizado ...
# ..                                                 ...
# 121                       5. Otros activos financieros
# 141                       5. Otros activos financieros
# 214                       5. Otros activos financieros
# 216                       5. Otros activos financieros
# 219                       5. Otros activos financieros
#
#                                                 Cuenta
# 4                        206 Aplicaciones informáticas
# 5                        206 Aplicaciones informáticas
# 6    2806 Amortización acumulada de aplicaciones in...
# 7    2806 Amortización acumulada de aplicaciones in...
# 10                                      216 Mobiliario
# ..                                                 ...
# 121                              4709 Hacienda Pública
# 141                                         572 Bancos
# 214                              4750 Hacienda Pública
# 216                              4751 Hacienda Pública
# 219              476 Organismos de la Seguridad Social
#
# [97 rows x 7 columns]

# %%
Balance['Cuenta'] = Balance['Cuenta'].where(pd.to_numeric(Balance['Subcuenta'].str.extract(r'^(\d+)')[0]) < 10000).ffill()

Balance['Cuenta'].where(pd.to_numeric(Balance['Subcuenta'].str.extract(r'^(\d+)')[0]) < 10000)
# Out:
# 4                          206 Aplicaciones informáticas
# 5                                                    NaN
# 6      2806 Amortización acumulada de aplicaciones in...
# 7                                                    NaN
# 10                                        216 Mobiliario
#                              ...
# 121                                4709 Hacienda Pública
# 141                                           572 Bancos
# 214                                4750 Hacienda Pública
# 216                                4751 Hacienda Pública
# 219                476 Organismos de la Seguridad Social
# Name: Cuenta, Length: 97, dtype: str

# %%
Balance = Balance[~(pd.to_numeric(Balance['Subcuenta'].str.extract(r'^(\d+)')[0]) < 10000)]

# %%
Balance
# Out:
#                                      Subcuenta         Valor Partida  \
# 5     20600001 - CASH LESS DESARROLLO SOFTWARE      923003,2  ACTIVO
# 7                28060001 - AMORTACUMCASH LESS  -851691,6196  ACTIVO
# 11             21600001 - 5 SILLAS ERGONOMICAS       2119,14  ACTIVO
# 12             21600002 - 5 MESAS OFICINA DEMI     1363,3134  ACTIVO
# 13                  21600003 - 5 CAJONERAS NIX     1226,7466  ACTIVO
# ..                                         ...           ...     ...
# 96         26000002 - FIANZA OFICINA BAILEN 71       4473,74  ACTIVO
# 97   26000003 - FIANZA PARKING ESTACIONAMIENTO       317,871  ACTIVO
# 98         26000004 - FIANZA AUTOMOVIL AUDI Q2    819,212432  ACTIVO
# 100              Activos por impuesto diferido   35926,46325  ACTIVO
# 102      47420000 - DCHOSDEDUCY BONI PTES APLI   35926,46325  ACTIVO
#
#               Subpartida                                     Grupo  \
# 5    Activo No Corriente                I. Inmovilizado intangible
# 7    Activo No Corriente                I. Inmovilizado intangible
# 11   Activo No Corriente                 II. Inmovilizado material
# 12   Activo No Corriente                 II. Inmovilizado material
# 13   Activo No Corriente                 II. Inmovilizado material
# ..                   ...                                       ...
# 96   Activo No Corriente  V. Inversiones financieras a largo plazo
# 97   Activo No Corriente  V. Inversiones financieras a largo plazo
# 98   Activo No Corriente  V. Inversiones financieras a largo plazo
# 100  Activo No Corriente         VI. Activos por impuesto diferido
# 102  Activo No Corriente         VI. Activos por impuesto diferido
#
#                                               SubGrupo  \
# 5                         5. Aplicaciones informáticas
# 7                         5. Aplicaciones informáticas
# 11   2. Instalaciones técnicas y otro inmovilizado ...
# 12   2. Instalaciones técnicas y otro inmovilizado ...
# 13   2. Instalaciones técnicas y otro inmovilizado ...
# ..                                                 ...
# 96                        5. Otros activos financieros
# 97                        5. Otros activos financieros
# 98                        5. Otros activos financieros
# 100                       5. Otros activos financieros
# 102                       5. Otros activos financieros
#
#                                                 Cuenta
# 5                        206 Aplicaciones informáticas
# 7    2806 Amortización acumulada de aplicaciones in...
# 11                                      216 Mobiliario
# 12                                      216 Mobiliario
# 13                                      216 Mobiliario
# ..                                                 ...
# 96   26 Fianzas y depósitos constituidos a largo plazo
# 97   26 Fianzas y depósitos constituidos a largo plazo
# 98   26 Fianzas y depósitos constituidos a largo plazo
# 100  26 Fianzas y depósitos constituidos a largo plazo
# 102                  474 Activos por impuesto diferido
#
# [83 rows x 7 columns]

# %%
# Configuración Año y Periodo (Establecidos en el inicio del script)

Año = BalanceFile[7:11]

Balance['Año'] = Año
Balance['Periodo'] = Periodo

# %% [markdown]
# * Ordenar Columnas:

# %%
Balance = Balance[['Año', 'Periodo', 'Partida', 'Subpartida', 'Grupo', 'SubGrupo', 'Cuenta', 'Subcuenta', 'Valor']]

# %%
Balance
# Out:
#       Año Periodo Partida           Subpartida  \
# 5    2024   Anual  ACTIVO  Activo No Corriente
# 7    2024   Anual  ACTIVO  Activo No Corriente
# 11   2024   Anual  ACTIVO  Activo No Corriente
# 12   2024   Anual  ACTIVO  Activo No Corriente
# 13   2024   Anual  ACTIVO  Activo No Corriente
# ..    ...     ...     ...                  ...
# 96   2024   Anual  ACTIVO  Activo No Corriente
# 97   2024   Anual  ACTIVO  Activo No Corriente
# 98   2024   Anual  ACTIVO  Activo No Corriente
# 100  2024   Anual  ACTIVO  Activo No Corriente
# 102  2024   Anual  ACTIVO  Activo No Corriente
#
#                                         Grupo  \
# 5                  I. Inmovilizado intangible
# 7                  I. Inmovilizado intangible
# 11                  II. Inmovilizado material
# 12                  II. Inmovilizado material
# 13                  II. Inmovilizado material
# ..                                        ...
# 96   V. Inversiones financieras a largo plazo
# 97   V. Inversiones financieras a largo plazo
# 98   V. Inversiones financieras a largo plazo
# 100         VI. Activos por impuesto diferido
# 102         VI. Activos por impuesto diferido
#
#                                               SubGrupo  \
# 5                         5. Aplicaciones informáticas
# 7                         5. Aplicaciones informáticas
# 11   2. Instalaciones técnicas y otro inmovilizado ...
# 12   2. Instalaciones técnicas y otro inmovilizado ...
# 13   2. Instalaciones técnicas y otro inmovilizado ...
# ..                                                 ...
# 96                        5. Otros activos financieros
# 97                        5. Otros activos financieros
# 98                        5. Otros activos financieros
# 100                       5. Otros activos financieros
# 102                       5. Otros activos financieros
#
#                                                 Cuenta  \
# 5                        206 Aplicaciones informáticas
# 7    2806 Amortización acumulada de aplicaciones in...
# 11                                      216 Mobiliario
# 12                                      216 Mobiliario
# 13                                      216 Mobiliario
# ..                                                 ...
# 96   26 Fianzas y depósitos constituidos a largo plazo
# 97   26 Fianzas y depósitos constituidos a largo plazo
# 98   26 Fianzas y depósitos constituidos a largo plazo
# 100  26 Fianzas y depósitos constituidos a largo plazo
# 102                  474 Activos por impuesto diferido
#
#                                      Subcuenta         Valor
# 5     20600001 - CASH LESS DESARROLLO SOFTWARE      923003,2
# 7                28060001 - AMORTACUMCASH LESS  -851691,6196
# 11             21600001 - 5 SILLAS ERGONOMICAS       2119,14
# 12             21600002 - 5 MESAS OFICINA DEMI     1363,3134
# 13                  21600003 - 5 CAJONERAS NIX     1226,7466
# ..                                         ...           ...
# 96         26000002 - FIANZA OFICINA BAILEN 71       4473,74
# 97   26000003 - FIANZA PARKING ESTACIONAMIENTO       317,871
# 98         26000004 - FIANZA AUTOMOVIL AUDI Q2    819,212432
# 100              Activos por impuesto diferido   35926,46325
# 102      47420000 - DCHOSDEDUCY BONI PTES APLI   35926,46325
#
# [83 rows x 9 columns]

# %% [markdown]
# * Pendiente Transformación: Desglosar Columnas correspondientes en {Id y Nombre}

# %%
# Division Columnas y creación columnas_id's: 

Balance[['Grupo_id', 'Grupo']] = Balance['Grupo'].str.split('. ', n = 1, expand = True)              # Grupo
Balance[['SubGrupo_id', 'SubGrupo']] = Balance['SubGrupo'].str.split('. ', n = 1, expand = True)     # SubGrupo
Balance[['Cuenta_id', 'Cuenta']] = Balance['Cuenta'].str.split(' ', n = 1, expand = True)            # Cuenta
Balance[['Subcuenta_id', 'Subcuenta']] = Balance['Subcuenta'].str.split(' - ', n = 1, expand = True) # Subcuenta

# %%
Balance.head(5)
# Out:
#      Año Periodo Partida           Subpartida                    Grupo  \
# 5   2024   Anual  ACTIVO  Activo No Corriente  Inmovilizado intangible
# 7   2024   Anual  ACTIVO  Activo No Corriente  Inmovilizado intangible
# 11  2024   Anual  ACTIVO  Activo No Corriente    Inmovilizado material
# 12  2024   Anual  ACTIVO  Activo No Corriente    Inmovilizado material
# 13  2024   Anual  ACTIVO  Activo No Corriente    Inmovilizado material
#
#                                              SubGrupo  \
# 5                           Aplicaciones informáticas
# 7                           Aplicaciones informáticas
# 11  Instalaciones técnicas y otro inmovilizado mat...
# 12  Instalaciones técnicas y otro inmovilizado mat...
# 13  Instalaciones técnicas y otro inmovilizado mat...
#
#                                                Cuenta  \
# 5                           Aplicaciones informáticas
# 7   Amortización acumulada de aplicaciones informá...
# 11                                         Mobiliario
# 12                                         Mobiliario
# 13                                         Mobiliario
#
#                         Subcuenta         Valor Grupo_id SubGrupo_id  \
# 5   CASH LESS DESARROLLO SOFTWARE      923003,2        I           5
# 7              AMORTACUMCASH LESS  -851691,6196        I           5
# 11           5 SILLAS ERGONOMICAS       2119,14       II           2
# 12           5 MESAS OFICINA DEMI     1363,3134       II           2
# 13                5 CAJONERAS NIX     1226,7466       II           2
#
#    Cuenta_id Subcuenta_id
# 5        206     20600001
# 7       2806     28060001
# 11       216     21600001
# 12       216     21600002
# 13       216     21600003

# %%
Balance.columns
# Out:
# Index(['Año', 'Periodo', 'Partida', 'Subpartida', 'Grupo', 'SubGrupo',
#        'Cuenta', 'Subcuenta', 'Valor', 'Grupo_id', 'SubGrupo_id', 'Cuenta_id',
#        'Subcuenta_id'],
#       dtype='str')

# %%
# Ordenamos el dataframe: 
Balance = Balance[['Año', 'Periodo', 'Partida', 'Subpartida', 'Grupo_id', 'Grupo', 'SubGrupo_id', 'SubGrupo',
                 'Cuenta_id', 'Cuenta', 'Subcuenta_id', 'Subcuenta', 'Valor']]

# %%
# Cambiamos tipo de dato de Valor de Object a Numeric:
Balance['Valor'] = Balance['Valor'].str.replace('.', '', regex=False)   # Elimina los puntos que separan miles
Balance['Valor'] = Balance['Valor'].str.replace(',', '.', regex=False)  # Reemplaza las comas por puntos decimales
Balance['Valor'] = pd.to_numeric(Balance['Valor'], errors='coerce')

# %%
Balance.head(10)
# Out:
#      Año Periodo Partida           Subpartida Grupo_id  \
# 5   2024   Anual  ACTIVO  Activo No Corriente        I
# 7   2024   Anual  ACTIVO  Activo No Corriente        I
# 11  2024   Anual  ACTIVO  Activo No Corriente       II
# 12  2024   Anual  ACTIVO  Activo No Corriente       II
# 13  2024   Anual  ACTIVO  Activo No Corriente       II
# 14  2024   Anual  ACTIVO  Activo No Corriente       II
# 15  2024   Anual  ACTIVO  Activo No Corriente       II
# 16  2024   Anual  ACTIVO  Activo No Corriente       II
# 17  2024   Anual  ACTIVO  Activo No Corriente       II
# 18  2024   Anual  ACTIVO  Activo No Corriente       II
#
#                       Grupo SubGrupo_id  \
# 5   Inmovilizado intangible           5
# 7   Inmovilizado intangible           5
# 11    Inmovilizado material           2
# 12    Inmovilizado material           2
# 13    Inmovilizado material           2
# 14    Inmovilizado material           2
# 15    Inmovilizado material           2
# 16    Inmovilizado material           2
# 17    Inmovilizado material           2
# 18    Inmovilizado material           2
#
#                                              SubGrupo Cuenta_id  \
# 5                           Aplicaciones informáticas       206
# 7                           Aplicaciones informáticas      2806
# 11  Instalaciones técnicas y otro inmovilizado mat...       216
# 12  Instalaciones técnicas y otro inmovilizado mat...       216
# 13  Instalaciones técnicas y otro inmovilizado mat...       216
# 14  Instalaciones técnicas y otro inmovilizado mat...       216
# 15  Instalaciones técnicas y otro inmovilizado mat...       216
# 16  Instalaciones técnicas y otro inmovilizado mat...       216
# 17  Instalaciones técnicas y otro inmovilizado mat...       216
# 18  Instalaciones técnicas y otro inmovilizado mat...       216
#
#                                                Cuenta Subcuenta_id  \
# 5                           Aplicaciones informáticas     20600001
# 7   Amortización acumulada de aplicaciones informá...     28060001
# 11                                         Mobiliario     21600001
# 12                                         Mobiliario     21600002
# 13                                         Mobiliario     21600003
# 14                                         Mobiliario     21600004
# 15                                         Mobiliario     21600005
# 16                                         Mobiliario     21600006
# 17                                         Mobiliario     21600007
# 18                                         Mobiliario     21600008
#
#                                             Subcuenta          Valor
# 5                       CASH LESS DESARROLLO SOFTWARE  923003.200000
# 7                                  AMORTACUMCASH LESS -851691.619600
# 11                               5 SILLAS ERGONOMICAS    2119.140000
# 12                               5 MESAS OFICINA DEMI    1363.313400
# 13                                    5 CAJONERAS NIX    1226.746600
# 14                               4 ARCHIVADORES CARIN    1874.261600
# 15                              6 ARCHIVADORES BISLEY    1935.481200
# 16                                   2 ARMARIOS CAPSA     899.457200
# 17                           4 PUF REDONDO O CUADRADO    1428.559366
# 18  MESA DE JUNTAS DE MEDIDAS 200X120 SOBRE LAMINA...    1272.190380

# %% [markdown]
# ### Resultado y Descarga:

# %%
Balance.head(4)
# Out:
#      Año Periodo Partida           Subpartida Grupo_id  \
# 5   2024   Anual  ACTIVO  Activo No Corriente        I
# 7   2024   Anual  ACTIVO  Activo No Corriente        I
# 11  2024   Anual  ACTIVO  Activo No Corriente       II
# 12  2024   Anual  ACTIVO  Activo No Corriente       II
#
#                       Grupo SubGrupo_id  \
# 5   Inmovilizado intangible           5
# 7   Inmovilizado intangible           5
# 11    Inmovilizado material           2
# 12    Inmovilizado material           2
#
#                                              SubGrupo Cuenta_id  \
# 5                           Aplicaciones informáticas       206
# 7                           Aplicaciones informáticas      2806
# 11  Instalaciones técnicas y otro inmovilizado mat...       216
# 12  Instalaciones técnicas y otro inmovilizado mat...       216
#
#                                                Cuenta Subcuenta_id  \
# 5                           Aplicaciones informáticas     20600001
# 7   Amortización acumulada de aplicaciones informá...     28060001
# 11                                         Mobiliario     21600001
# 12                                         Mobiliario     21600002
#
#                         Subcuenta        Valor
# 5   CASH LESS DESARROLLO SOFTWARE  923003.2000
# 7              AMORTACUMCASH LESS -851691.6196
# 11           5 SILLAS ERGONOMICAS    2119.1400
# 12           5 MESAS OFICINA DEMI    1363.3134

# %%
### Descarga arhivo: 
NombreArchivo = f"File.Balance{Año}.csv"
Balance.to_csv(NombreArchivo, index=False)

# %%
f"Archivo creado llamado: 'File.Balance{Año}.csv'"
# Out:
# "Archivo creado llamado: 'File.Balance2024.csv'"
